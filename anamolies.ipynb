# %%
# !pip install adtk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 KB 7.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from adtk.data import validate_series
from adtk.visualization import plot
from adtk.detector import *

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c042dfad-0aa3-4601-8204-b24e5a4f854f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c042dfad-0aa3-4601-8204-b24e5a4f854f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('final4_Copy.csv')
data.head()
# Out:
#              Date  Temperature  Pressure  ExternalTemp1  Humidity
# 0  8/20/2022 2:03         17.9  1008.100           19.4        81
# 1  8/20/2022 2:13         17.9  1008.001           19.4        81
# 2  8/20/2022 2:23         32.0  1007.877           19.3        81
# 3  8/20/2022 2:33         17.8  1007.949           19.3        81
# 4  8/20/2022 2:53         18.0  1007.808           19.3        81

# %%
data['Date'] = pd.to_datetime(data['Date'])
data= data.set_index('Date')
data=data['Temperature']

# %%
threshold_detector= ThresholdAD(low=-14,high=20)
anomalies = threshold_detector.detect(data)
plot(data,anomaly= anomalies,anomaly_color="red",anomaly_tag="marker")
plt.show()

# %%
data2 = pd.read_csv('final4_Copy.csv')
data2.head()
# Out:
#              Date  Temperature  Pressure  ExternalTemp1  Humidity
# 0  8/20/2022 2:03         17.9  1008.100           19.4        81
# 1  8/20/2022 2:13         17.9  1008.001           19.4        81
# 2  8/20/2022 2:23         32.0  1007.877           19.3        81
# 3  8/20/2022 2:33         17.8  1007.949           19.3        81
# 4  8/20/2022 2:53         18.0  1007.808           19.3        81

# %%
data2['Date'] = pd.to_datetime(data2['Date'])
data2= data2.set_index('Date')
data2=data2['Pressure']

# %%
threshold_detector= ThresholdAD(low=-14,high=20)
anomalies = threshold_detector.detect(data2)
plot(data,anomaly= anomalies,anomaly_color="red",anomaly_tag="marker")
plt.show()
