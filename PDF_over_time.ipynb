# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3dd54cd-5dea-4c65-90e9-25940c4702c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3dd54cd-5dea-4c65-90e9-25940c4702c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('final4.csv')

# %%
df=pd.DataFrame(data['Temperature'])

# %%
ax=data.plot.kde()

# %%
ay=df.plot.kde()

# %%
df=pd.DataFrame(data['Pressure'])

# %%
az=df.plot.kde()

# %%
df=pd.DataFrame(data['Humidity'])
az=df.plot.kde()

# %%
data = pd.read_csv('final4.csv')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
grouped_data = data.groupby(['Date'])

# %%
pdf_data = grouped_data['Temperature'].apply(lambda x: pd.Series(np.histogram(x, bins='auto', density=True)[0]))

# %%
pdf_data.plot(kind='density', figsize=(12,10))
plt.show()

# %%
df = pd.read_csv('final4.csv', parse_dates=['Date'])
df
# Out:
#                      Date  Temperature  Pressure  ExternalTemp1  Humidity
# 0     2022-08-20 02:03:26         17.9  1008.100           19.4        81
# 1     2022-08-20 02:13:26         17.9  1008.001           19.4        81
# 2     2022-08-20 02:23:26         17.9  1007.877           19.3        81
# 3     2022-08-20 02:33:26         17.8  1007.949           19.3        81
# 4     2022-08-20 02:53:27         18.0  1007.808           19.3        81
# ...                   ...          ...       ...            ...       ...
# 29610 2023-03-25 23:44:43         -0.2   993.385            0.0        92
# 29611 2023-03-25 23:54:43         -0.2   993.471            0.0        92
# 29612 2023-03-26 00:04:43         -0.2   993.390            0.0        92
# 29613 2023-03-26 00:14:43         -0.3   993.486            0.0        92
# 29614 2023-03-26 00:24:43         -0.2   993.477            0.0        92
#
# [29615 rows x 5 columns]

# %%
df.set_index('Date', inplace=True)

# %%
window_size = '1M' # 1 month
step_size = '1D' # 1 day

# %%
pdfs = []

# %%
start_date = df.index.min()
start_date
end_date = df.index.max()
end_date
# Out:
# 29614

# %%
column_name = 'Pressure'

# %%
column_data = df[column_name]

# %%
pdf = column_data.plot(kind='density')
pdf.set_xlabel(column_name)
pdf.set_ylabel('Density')
pdf.set_title(f'PDF of {column_name}')
plt.show()

# %%
# Out:
# Text(0.5, 1.0, 'PDF of Temperature')

# %%
plt.show()

# %%
df= pd.read_csv('final4.csv')

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.set_index("Date", inplace=True)

# %%
df["Temperature"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(data=df, x="Date", y="Temperature", ax=ax)
ax.set_xlabel("Date")
#plt.xticks(rotation=45)
ax.set_ylabel("Temperature PDF")
plt.show()
